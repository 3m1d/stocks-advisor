# %% [markdown]
# # TFT модель для предсказания стоимости акций
#
# TFT (Temporal Fusion Transformer) - модель анализа временных рядов на основе архитектуры "трансформер". Эта модель может прогнозировать сразу весь необходимый нам горизонт, без накопления ошибки. А ещё мы можем обучить всего одну модель на нескольких таргетах сразу, то есть будет одна модель для нескольких акций.
#
# План такой:
# - Основные признаки + таргет: GAZP, LKOH, ROSN, SBER
# - Внешние признаки: USDRUB, EURRUB, CNYRUB, GLDRUB, Brent, IMOEX

# %%
# Хак, чтобы добавить корень проекта в path для импорта модулей
import sys
from pathlib import Path

sys.path.append(str(Path().resolve().parents[1]))
sys.path
# Out:
# ['/home/fiberfox/.local/share/uv/python/cpython-3.12.7-linux-x86_64-gnu/lib/python312.zip',
#  '/home/fiberfox/.local/share/uv/python/cpython-3.12.7-linux-x86_64-gnu/lib/python3.12',
#  '/home/fiberfox/.local/share/uv/python/cpython-3.12.7-linux-x86_64-gnu/lib/python3.12/lib-dynload',
#  '',
#  '/home/fiberfox/Projects/HSEAIMag2025/stocks-advisor/.venv/lib/python3.12/site-packages',
#  '/home/fiberfox/Projects/HSEAIMag2025/stocks-advisor']
